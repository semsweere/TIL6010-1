# %% [markdown]
# ## General requirements for the assignment
# - Make appropriate comments to your code
# - Use Markdown cells to provide your answers (when applicable)
# - Add your code when there is the comment "YOUR CODE HERE".
# - Stick to Pep8 standard as much as possible for your coding
# - Submit through GitHub
# - Tag the commit as *Final submission of Assignment 1*
# - Post (interesting) errors in the course Github's issue page
#
# ## Assignment Intro
# In this assignment, you will be working with data imports. Data is provided to you both to be downloaded locally and accessed remotely. The final deliverable for the assignment is this ipython notebook with the executed cells active and submitted through your personal GitHub accounts. You will be importing data, conduct some basic data exploration and finally exporting the data and saving it for future use.
#
# You will be working with this data for the other two GO/NOGO assignments as well. The data is from the Google mobility report. You can find more information about this data here: <https://www.google.com/covid19/mobility/data_documentation.html?hl=en>.
#
# ### DEADLINE FOR THIS ASSIGNMENT IS 17 SEPTEMBER 2021 BEFORE 23:59
#
# <hr />

# %% [markdown]
# ## Import libraries
# Update this list as you go along with the assignment

# %%
import pandas as pd 
import os

# %% [markdown]
# # PART I - Data Import and Export

# %% [markdown]
# #### 1. Download mobility data from this [link](https://www.google.com/covid19/mobility/), choose *Region CSVs*. From the downloaded data, pick a country to work with. Why did you choose this country?

# %%
# path to the downloaded data folder, e.g. 'Downloads/Region_Mobility_Report_CSVs/'
data_dir ='C:/Users/leenvanderzwan/Downloads/Region_Mobility_Report_CSVs/'
country_code = "NL"

# %% [markdown]
# #### 2. Find the path to the data of your selection. We have prepared some sample code. You need to fill in some parts indicated by 'YOUR CODE HERE'.

# %%
all_files = os.listdir(data_dir)
# initilisation
target_file_name = ''
year = '2020'

for file_name in all_files:
    # check if this file is for 2020
    is_year = year 
    # if yes, we check if the file name is for the country that you select
    if is_year:
        # check if the country_code is in the file_name
        is_country = country_code
        if is_country in file_name:
            # found the file, save it to 'target_file_name'
            target_file_name = file_name 
            # we stop looking by breaking out of the for loop
            break
if not target_file_name:
    print('File not found. Check your country code (or select a different one)!')
else:
    print('Found file name is: ' + target_file_name)
    # get the path to the file
    file_path = 'C:/Users/leenvanderzwan/Downloads/Region_Mobility_Report_CSVs/'+year+'_'+country_code+'_Region_mobility_Report.csv'
    print('Path to the file is: ' + file_path)
# Out:
# Found file name is: 2020_NL_Region_Mobility_Report.csv
# Path to the file is: C:/Users/leenvanderzwan/Downloads/Region_Mobility_Report_CSVs/2020_NL_Region_mobility_Report.csv

# %% [markdown]
# #### 3. Import the 2020 data for this country as a pandas data frame and name it as `df_2020`. Print the first 10 lines of `df_2020`

# %%
df_2020 = pd.read_csv(file_path)
df_2020.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
# 5                  NL    Netherlands          NaN          NaN         NaN
# 6                  NL    Netherlands          NaN          NaN         NaN
# 7                  NL    Netherlands          NaN          NaN         NaN
# 8                  NL    Netherlands          NaN          NaN         NaN
# 9                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-15
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-16
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-17
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-18
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-19
# 5             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-20
# 6             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-21
# 7             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-22
# 8             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-23
# 9             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-24
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                1.0
# 1                                              -10.0
# 2                                                0.0
# 3                                                5.0
# 4                                                3.0
# 5                                                1.0
# 6                                                8.0
# 7                                                1.0
# 8                                                1.0
# 9                                                9.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                1.0
# 1                                               -8.0
# 2                                               -1.0
# 3                                                4.0
# 4                                                0.0
# 5                                               -1.0
# 6                                                4.0
# 7                                               -2.0
# 8                                              -11.0
# 9                                               -7.0
#
#    parks_percent_change_from_baseline  \
# 0                                11.0
# 1                               -31.0
# 2                                 8.0
# 3                                21.0
# 4                                20.0
# 5                                -5.0
# 6                                22.0
# 7                                -2.0
# 8                               -26.0
# 9                                 4.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                           -5.0
# 2                                           -3.0
# 3                                           -3.0
# 4                                           -3.0
# 5                                           -3.0
# 6                                            1.0
# 7                                           10.0
# 8                                            2.0
# 9                                           -4.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                     -3.0
# 2                                     -5.0
# 3                                     -5.0
# 4                                     -5.0
# 5                                     -6.0
# 6                                     -9.0
# 7                                     -4.0
# 8                                     -3.0
# 9                                    -21.0
#
#    residential_percent_change_from_baseline
# 0                                       0.0
# 1                                       2.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
# 5                                       1.0
# 6                                       0.0
# 7                                       0.0
# 8                                       0.0
# 9                                       3.0

# %% [markdown]
# #### We have also stored the data in a remote server. The data for a particular country can be retrieved with the following API:
# `http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/{yy}/{CC}`
# #### where yy is either 2020 or 2021, and CC is a 2-letter country code. For example, to get data for 2020 for the Netherlands, the API will be: <http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/2020/NL>

# %% [markdown]
# #### 4. Download the mobility report data of **2021** for the same country (that you have chosen above) using this API and name it as `df_2021`.  Print the first 10 lines of the dataframe

# %%
Report_data = "http://mirrors-dev.citg.tudelft.nl:8083/google-mobility-data/2021/NL"
df_2021 = pd.read_csv(Report_data)
df_2021.head(10)
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
# 5                  NL    Netherlands          NaN          NaN         NaN
# 6                  NL    Netherlands          NaN          NaN         NaN
# 7                  NL    Netherlands          NaN          NaN         NaN
# 8                  NL    Netherlands          NaN          NaN         NaN
# 9                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-01
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-02
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-03
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-04
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-05
# 5             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-06
# 6             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-07
# 7             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-08
# 8             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-09
# 9             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2021-01-10
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                              -79.0
# 1                                              -65.0
# 2                                              -62.0
# 3                                              -52.0
# 4                                              -52.0
# 5                                              -53.0
# 6                                              -58.0
# 7                                              -55.0
# 8                                              -59.0
# 9                                              -60.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                              -77.0
# 1                                              -17.0
# 2                                              -19.0
# 3                                              -12.0
# 4                                               -8.0
# 5                                               -9.0
# 6                                              -15.0
# 7                                               -9.0
# 8                                               -9.0
# 9                                              -14.0
#
#    parks_percent_change_from_baseline  \
# 0                                 5.0
# 1                                 0.0
# 2                                 3.0
# 3                               -23.0
# 4                                -8.0
# 5                                -2.0
# 6                               -32.0
# 7                                 0.0
# 8                                19.0
# 9                                23.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                          -75.0
# 1                                          -59.0
# 2                                          -56.0
# 3                                          -62.0
# 4                                          -61.0
# 5                                          -58.0
# 6                                          -62.0
# 7                                          -57.0
# 8                                          -52.0
# 9                                          -52.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                    -83.0
# 1                                    -22.0
# 2                                    -12.0
# 3                                    -41.0
# 4                                    -41.0
# 5                                    -37.0
# 6                                    -39.0
# 7                                    -35.0
# 8                                    -12.0
# 9                                     -9.0
#
#    residential_percent_change_from_baseline
# 0                                      24.0
# 1                                      12.0
# 2                                       8.0
# 3                                      16.0
# 4                                      16.0
# 5                                      15.0
# 6                                      17.0
# 7                                      15.0
# 8                                      10.0
# 9                                       7.0

# %% [markdown]
# #### 5. Combine the two dataframes `df_2020` and `df_2021` into a new dataframe `df`. Print the last 10 lines of `df`.

# %%
df = pd.concat([df_2020, df_2021], ignore_index = True)
df.tail(10)
# Out:
#        country_region_code country_region sub_region_1 sub_region_2  \
# 198780                  NL    Netherlands      Zeeland        Veere
# 198781                  NL    Netherlands      Zeeland        Veere
# 198782                  NL    Netherlands      Zeeland        Veere
# 198783                  NL    Netherlands      Zeeland        Veere
# 198784                  NL    Netherlands      Zeeland        Veere
# 198785                  NL    Netherlands      Zeeland        Veere
# 198786                  NL    Netherlands      Zeeland        Veere
# 198787                  NL    Netherlands      Zeeland        Veere
# 198788                  NL    Netherlands      Zeeland        Veere
# 198789                  NL    Netherlands      Zeeland        Veere
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 198780         NaN             NaN               NaN
# 198781         NaN             NaN               NaN
# 198782         NaN             NaN               NaN
# 198783         NaN             NaN               NaN
# 198784         NaN             NaN               NaN
# 198785         NaN             NaN               NaN
# 198786         NaN             NaN               NaN
# 198787         NaN             NaN               NaN
# 198788         NaN             NaN               NaN
# 198789         NaN             NaN               NaN
#
#                            place_id        date  \
# 198780  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-23
# 198781  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-24
# 198782  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-25
# 198783  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-26
# 198784  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-27
# 198785  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-28
# 198786  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-29
# 198787  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-30
# 198788  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-08-31
# 198789  ChIJa7uf-GcjxEcRpGJlbS6aq8s  2021-09-01
#
#         retail_and_recreation_percent_change_from_baseline  \
# 198780                                                NaN
# 198781                                                NaN
# 198782                                                NaN
# 198783                                                NaN
# 198784                                                NaN
# 198785                                                NaN
# 198786                                                NaN
# 198787                                                NaN
# 198788                                                NaN
# 198789                                                NaN
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 198780                                                NaN
# 198781                                                NaN
# 198782                                                NaN
# 198783                                                NaN
# 198784                                                NaN
# 198785                                                NaN
# 198786                                                NaN
# 198787                                                NaN
# 198788                                                NaN
# 198789                                                NaN
#
#         parks_percent_change_from_baseline  \
# 198780                                 NaN
# 198781                                 NaN
# 198782                                 NaN
# 198783                                 NaN
# 198784                                 NaN
# 198785                               311.0
# 198786                               237.0
# 198787                                 NaN
# 198788                                 NaN
# 198789                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 198780                                            NaN
# 198781                                            NaN
# 198782                                            NaN
# 198783                                            NaN
# 198784                                            NaN
# 198785                                            NaN
# 198786                                            NaN
# 198787                                            NaN
# 198788                                            NaN
# 198789                                            NaN
#
#         workplaces_percent_change_from_baseline  \
# 198780                                    -29.0
# 198781                                    -24.0
# 198782                                    -29.0
# 198783                                    -29.0
# 198784                                    -23.0
# 198785                                      NaN
# 198786                                      NaN
# 198787                                    -20.0
# 198788                                    -15.0
# 198789                                    -19.0
#
#         residential_percent_change_from_baseline
# 198780                                       4.0
# 198781                                       3.0
# 198782                                       4.0
# 198783                                       6.0
# 198784                                       3.0
# 198785                                       NaN
# 198786                                       NaN
# 198787                                       4.0
# 198788                                       3.0
# 198789                                       3.0

# %% [markdown]
# #### 6. `df` now contains mobility data for your selected country from 2020 and 2021. There are three aggregation levels to this data, namely national (`country_region`), provincial (`sub_region_1`), and city (`sub_region_2`). Separate these data into three different dataframes, namely `df_nation`, `df_province`, and `df_city`.  Print the first 5 lines of each of them.
#
# Hint:
# - For the national data, `sub_region_1` and `sub_region_2` are NaN.
# - For the provincial data, `sub_region_2` is NaN.
# - For the city data, `country_region`, `sub_region_1` and `sub_region_2` are not NaN.
# - Logical operators: <https://realpython.com/python-bitwise-operators/>
# - Use pandas [isna()](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html) function

# %%
df_nation = df[df['sub_region_1' and 'sub_region_2'].isna()]
display(df_nation.head(5))

df_province = df[df['sub_region_2'].isna()]
display(df_province.head(5))

df_city = df[df['sub_region_1' and 'sub_region_2' and 'country_region'].notna()]
display(df_city.head(5))
# Out:
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-15
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-16
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-17
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-18
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                1.0
# 1                                              -10.0
# 2                                                0.0
# 3                                                5.0
# 4                                                3.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                1.0
# 1                                               -8.0
# 2                                               -1.0
# 3                                                4.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                11.0
# 1                               -31.0
# 2                                 8.0
# 3                                21.0
# 4                                20.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                           -5.0
# 2                                           -3.0
# 3                                           -3.0
# 4                                           -3.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                     -3.0
# 2                                     -5.0
# 3                                     -5.0
# 4                                     -5.0
#
#    residential_percent_change_from_baseline
# 0                                       0.0
# 1                                       2.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-15
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-16
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-17
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-18
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                1.0
# 1                                              -10.0
# 2                                                0.0
# 3                                                5.0
# 4                                                3.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                1.0
# 1                                               -8.0
# 2                                               -1.0
# 3                                                4.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                11.0
# 1                               -31.0
# 2                                 8.0
# 3                                21.0
# 4                                20.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                           -5.0
# 2                                           -3.0
# 3                                           -3.0
# 4                                           -3.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                     -3.0
# 2                                     -5.0
# 3                                     -5.0
# 4                                     -5.0
#
#    residential_percent_change_from_baseline
# 0                                       0.0
# 1                                       2.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0
#   country_region_code country_region sub_region_1 sub_region_2  metro_area  \
# 0                  NL    Netherlands          NaN          NaN         NaN
# 1                  NL    Netherlands          NaN          NaN         NaN
# 2                  NL    Netherlands          NaN          NaN         NaN
# 3                  NL    Netherlands          NaN          NaN         NaN
# 4                  NL    Netherlands          NaN          NaN         NaN
#
#   iso_3166_2_code  census_fips_code                     place_id        date  \
# 0             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-15
# 1             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-16
# 2             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-17
# 3             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-18
# 4             NaN               NaN  ChIJu-SH28MJxkcRnwq9_851obM  2020-02-19
#
#    retail_and_recreation_percent_change_from_baseline  \
# 0                                                1.0
# 1                                              -10.0
# 2                                                0.0
# 3                                                5.0
# 4                                                3.0
#
#    grocery_and_pharmacy_percent_change_from_baseline  \
# 0                                                1.0
# 1                                               -8.0
# 2                                               -1.0
# 3                                                4.0
# 4                                                0.0
#
#    parks_percent_change_from_baseline  \
# 0                                11.0
# 1                               -31.0
# 2                                 8.0
# 3                                21.0
# 4                                20.0
#
#    transit_stations_percent_change_from_baseline  \
# 0                                            3.0
# 1                                           -5.0
# 2                                           -3.0
# 3                                           -3.0
# 4                                           -3.0
#
#    workplaces_percent_change_from_baseline  \
# 0                                      0.0
# 1                                     -3.0
# 2                                     -5.0
# 3                                     -5.0
# 4                                     -5.0
#
#    residential_percent_change_from_baseline
# 0                                       0.0
# 1                                       2.0
# 2                                       1.0
# 3                                       1.0
# 4                                       1.0

# %% [markdown]
# #### 7. Save `df_nation`, `df_province`, and `df_city` into csv files under folder 'processed_data', and locate this folder under `data_dir`. Name the files `{CC}_nation.csv`, `{CC}_province.csv`, and `{CC}_city.csv`, respectively. `{CC}` stands for your selected country code.

# %%
# YOUR CODE HERE

# %% [markdown]
# <hr />

# %% [markdown]
# # PART II - Simple Data Processing

# %% [markdown]
# #### 1. There are multiple activities in the mobility report such as workplaces, parks, transit stations, etc. For each of the activities, what are the average percent changes from baselines for your selected country?

# %%
mean = df_2020.mean()
print(mean)

# %% [markdown]
# #### 2. Let's look into data from different provinces. How many provinces are there in the data of your selected country? Print all of them.

# %%
print(df['sub_region_1'].dropna().unique())
# Out:
# ['Drenthe' 'Flevoland' 'Friesland' 'Gelderland' 'Groningen' 'Limburg'
#  'North Brabant' 'North Holland' 'Overijssel' 'South Holland' 'Utrecht'
#  'Zeeland']

# %% [markdown]
# #### 3. You can get a summary of each of the provinces using pandas describe function. Using this, find which province experienced the largest (average) changes in workplaces.

# %%
province = df_2020.groupby('sub_region_1')
print(province,workplaces_percent_change_from_baseline.describe())
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-59-ddfd71805ac9> in <module>
#       1 province = df_2020.groupby('sub_region_1')
# ----> 2 print(province,workplaces_percent_change_from_baseline.describe())
#
# NameError: name 'workplaces_percent_change_from_baseline' is not defined

# %% [markdown]
# #### 4. Create a new dataframe that only contains data from the province with the largest changes in workplaces, which you found in the previous question.

# %%
Utrecht = province.get_group('Utrecht')

# %% [markdown]
# #### 5. We're going to look at the changes of this province over time. As you can see, the column date is in string format. Convert this str date column data str to datetime format and append as an extra column called 'date2' to the dataframe.
# Hint: <https://pandas.pydata.org/docs/reference/api/pandas.to_datetime.html>

# %%
Utrecht['date2'] = pd.to_datetime(Utrecht['date'])
display(Utrecht)
# Out:
# C:\Users\leenvanderzwan\Documents\school\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
#        country_region_code country_region sub_region_1 sub_region_2  \
# 98786                   NL    Netherlands      Utrecht          NaN
# 98787                   NL    Netherlands      Utrecht          NaN
# 98788                   NL    Netherlands      Utrecht          NaN
# 98789                   NL    Netherlands      Utrecht          NaN
# 98790                   NL    Netherlands      Utrecht          NaN
# 98791                   NL    Netherlands      Utrecht          NaN
# 98792                   NL    Netherlands      Utrecht          NaN
# 98793                   NL    Netherlands      Utrecht          NaN
# 98794                   NL    Netherlands      Utrecht          NaN
# 98795                   NL    Netherlands      Utrecht          NaN
# 98796                   NL    Netherlands      Utrecht          NaN
# 98797                   NL    Netherlands      Utrecht          NaN
# 98798                   NL    Netherlands      Utrecht          NaN
# 98799                   NL    Netherlands      Utrecht          NaN
# 98800                   NL    Netherlands      Utrecht          NaN
# 98801                   NL    Netherlands      Utrecht          NaN
# 98802                   NL    Netherlands      Utrecht          NaN
# 98803                   NL    Netherlands      Utrecht          NaN
# 98804                   NL    Netherlands      Utrecht          NaN
# 98805                   NL    Netherlands      Utrecht          NaN
# 98806                   NL    Netherlands      Utrecht          NaN
# 98807                   NL    Netherlands      Utrecht          NaN
# 98808                   NL    Netherlands      Utrecht          NaN
# 98809                   NL    Netherlands      Utrecht          NaN
# 98810                   NL    Netherlands      Utrecht          NaN
# 98811                   NL    Netherlands      Utrecht          NaN
# 98812                   NL    Netherlands      Utrecht          NaN
# 98813                   NL    Netherlands      Utrecht          NaN
# 98814                   NL    Netherlands      Utrecht          NaN
# 98815                   NL    Netherlands      Utrecht          NaN
# ...                    ...            ...          ...          ...
# 106251                  NL    Netherlands      Utrecht        Zeist
# 106252                  NL    Netherlands      Utrecht        Zeist
# 106253                  NL    Netherlands      Utrecht        Zeist
# 106254                  NL    Netherlands      Utrecht        Zeist
# 106255                  NL    Netherlands      Utrecht        Zeist
# 106256                  NL    Netherlands      Utrecht        Zeist
# 106257                  NL    Netherlands      Utrecht        Zeist
# 106258                  NL    Netherlands      Utrecht        Zeist
# 106259                  NL    Netherlands      Utrecht        Zeist
# 106260                  NL    Netherlands      Utrecht        Zeist
# 106261                  NL    Netherlands      Utrecht        Zeist
# 106262                  NL    Netherlands      Utrecht        Zeist
# 106263                  NL    Netherlands      Utrecht        Zeist
# 106264                  NL    Netherlands      Utrecht        Zeist
# 106265                  NL    Netherlands      Utrecht        Zeist
# 106266                  NL    Netherlands      Utrecht        Zeist
# 106267                  NL    Netherlands      Utrecht        Zeist
# 106268                  NL    Netherlands      Utrecht        Zeist
# 106269                  NL    Netherlands      Utrecht        Zeist
# 106270                  NL    Netherlands      Utrecht        Zeist
# 106271                  NL    Netherlands      Utrecht        Zeist
# 106272                  NL    Netherlands      Utrecht        Zeist
# 106273                  NL    Netherlands      Utrecht        Zeist
# 106274                  NL    Netherlands      Utrecht        Zeist
# 106275                  NL    Netherlands      Utrecht        Zeist
# 106276                  NL    Netherlands      Utrecht        Zeist
# 106277                  NL    Netherlands      Utrecht        Zeist
# 106278                  NL    Netherlands      Utrecht        Zeist
# 106279                  NL    Netherlands      Utrecht        Zeist
# 106280                  NL    Netherlands      Utrecht        Zeist
#
#         metro_area iso_3166_2_code  census_fips_code  \
# 98786          NaN           NL-UT               NaN
# 98787          NaN           NL-UT               NaN
# 98788          NaN           NL-UT               NaN
# 98789          NaN           NL-UT               NaN
# 98790          NaN           NL-UT               NaN
# 98791          NaN           NL-UT               NaN
# 98792          NaN           NL-UT               NaN
# 98793          NaN           NL-UT               NaN
# 98794          NaN           NL-UT               NaN
# 98795          NaN           NL-UT               NaN
# 98796          NaN           NL-UT               NaN
# 98797          NaN           NL-UT               NaN
# 98798          NaN           NL-UT               NaN
# 98799          NaN           NL-UT               NaN
# 98800          NaN           NL-UT               NaN
# 98801          NaN           NL-UT               NaN
# 98802          NaN           NL-UT               NaN
# 98803          NaN           NL-UT               NaN
# 98804          NaN           NL-UT               NaN
# 98805          NaN           NL-UT               NaN
# 98806          NaN           NL-UT               NaN
# 98807          NaN           NL-UT               NaN
# 98808          NaN           NL-UT               NaN
# 98809          NaN           NL-UT               NaN
# 98810          NaN           NL-UT               NaN
# 98811          NaN           NL-UT               NaN
# 98812          NaN           NL-UT               NaN
# 98813          NaN           NL-UT               NaN
# 98814          NaN           NL-UT               NaN
# 98815          NaN           NL-UT               NaN
# ...            ...             ...               ...
# 106251         NaN             NaN               NaN
# 106252         NaN             NaN               NaN
# 106253         NaN             NaN               NaN
# 106254         NaN             NaN               NaN
# 106255         NaN             NaN               NaN
# 106256         NaN             NaN               NaN
# 106257         NaN             NaN               NaN
# 106258         NaN             NaN               NaN
# 106259         NaN             NaN               NaN
# 106260         NaN             NaN               NaN
# 106261         NaN             NaN               NaN
# 106262         NaN             NaN               NaN
# 106263         NaN             NaN               NaN
# 106264         NaN             NaN               NaN
# 106265         NaN             NaN               NaN
# 106266         NaN             NaN               NaN
# 106267         NaN             NaN               NaN
# 106268         NaN             NaN               NaN
# 106269         NaN             NaN               NaN
# 106270         NaN             NaN               NaN
# 106271         NaN             NaN               NaN
# 106272         NaN             NaN               NaN
# 106273         NaN             NaN               NaN
# 106274         NaN             NaN               NaN
# 106275         NaN             NaN               NaN
# 106276         NaN             NaN               NaN
# 106277         NaN             NaN               NaN
# 106278         NaN             NaN               NaN
# 106279         NaN             NaN               NaN
# 106280         NaN             NaN               NaN
#
#                            place_id        date  \
# 98786   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-15
# 98787   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-16
# 98788   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-17
# 98789   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-18
# 98790   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-19
# 98791   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-20
# 98792   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-21
# 98793   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-22
# 98794   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-23
# 98795   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-24
# 98796   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-25
# 98797   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-26
# 98798   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-27
# 98799   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-28
# 98800   ChIJPzM8M01oxkcRsFwejVreAAM  2020-02-29
# 98801   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-01
# 98802   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-02
# 98803   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-03
# 98804   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-04
# 98805   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-05
# 98806   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-06
# 98807   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-07
# 98808   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-08
# 98809   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-09
# 98810   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-10
# 98811   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-11
# 98812   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-12
# 98813   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-13
# 98814   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-14
# 98815   ChIJPzM8M01oxkcRsFwejVreAAM  2020-03-15
# ...                             ...         ...
# 106251  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-02
# 106252  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-03
# 106253  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-04
# 106254  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-05
# 106255  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-06
# 106256  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-07
# 106257  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-08
# 106258  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-09
# 106259  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-10
# 106260  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-11
# 106261  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-12
# 106262  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-13
# 106263  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-14
# 106264  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-15
# 106265  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-16
# 106266  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-17
# 106267  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-18
# 106268  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-19
# 106269  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-20
# 106270  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-21
# 106271  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-22
# 106272  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-23
# 106273  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-24
# 106274  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-25
# 106275  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-26
# 106276  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-27
# 106277  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-28
# 106278  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-29
# 106279  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-30
# 106280  ChIJI1LXZIhCxkcR3IgumEta7x0  2020-12-31
#
#         retail_and_recreation_percent_change_from_baseline  \
# 98786                                                 8.0
# 98787                                                -5.0
# 98788                                                 2.0
# 98789                                                 4.0
# 98790                                                 6.0
# 98791                                                 0.0
# 98792                                                 8.0
# 98793                                                 4.0
# 98794                                                 4.0
# 98795                                                 0.0
# 98796                                                13.0
# 98797                                                 6.0
# 98798                                                -5.0
# 98799                                                 2.0
# 98800                                                 0.0
# 98801                                                 9.0
# 98802                                                -5.0
# 98803                                                 3.0
# 98804                                                 9.0
# 98805                                                -9.0
# 98806                                                 0.0
# 98807                                                 3.0
# 98808                                                 4.0
# 98809                                                 1.0
# 98810                                                -4.0
# 98811                                                 3.0
# 98812                                               -11.0
# 98813                                               -15.0
# 98814                                               -16.0
# 98815                                               -26.0
# ...                                                   ...
# 106251                                               -9.0
# 106252                                              -15.0
# 106253                                              -12.0
# 106254                                              -16.0
# 106255                                              -17.0
# 106256                                              -15.0
# 106257                                              -10.0
# 106258                                              -18.0
# 106259                                              -16.0
# 106260                                              -22.0
# 106261                                              -18.0
# 106262                                              -15.0
# 106263                                               24.0
# 106264                                              -37.0
# 106265                                              -38.0
# 106266                                              -39.0
# 106267                                              -38.0
# 106268                                              -42.0
# 106269                                              -27.0
# 106270                                              -28.0
# 106271                                              -21.0
# 106272                                              -27.0
# 106273                                              -26.0
# 106274                                              -84.0
# 106275                                              -77.0
# 106276                                              -53.0
# 106277                                              -22.0
# 106278                                              -28.0
# 106279                                              -28.0
# 106280                                              -30.0
#
#         grocery_and_pharmacy_percent_change_from_baseline  \
# 98786                                                 0.0
# 98787                                               -10.0
# 98788                                                -1.0
# 98789                                                 3.0
# 98790                                                -1.0
# 98791                                                -2.0
# 98792                                                -1.0
# 98793                                                -6.0
# 98794                                               -17.0
# 98795                                               -13.0
# 98796                                                 3.0
# 98797                                                -8.0
# 98798                                                -7.0
# 98799                                                -6.0
# 98800                                                -3.0
# 98801                                                -2.0
# 98802                                                -7.0
# 98803                                                 5.0
# 98804                                                 0.0
# 98805                                                -3.0
# 98806                                                 2.0
# 98807                                                 0.0
# 98808                                                -5.0
# 98809                                                -1.0
# 98810                                                -2.0
# 98811                                                 2.0
# 98812                                                12.0
# 98813                                                21.0
# 98814                                                 8.0
# 98815                                                 7.0
# ...                                                   ...
# 106251                                                5.0
# 106252                                                5.0
# 106253                                                9.0
# 106254                                                0.0
# 106255                                              -11.0
# 106256                                               -7.0
# 106257                                                1.0
# 106258                                               -5.0
# 106259                                                3.0
# 106260                                               -1.0
# 106261                                               -2.0
# 106262                                                4.0
# 106263                                               22.0
# 106264                                                1.0
# 106265                                                1.0
# 106266                                                9.0
# 106267                                                5.0
# 106268                                               -2.0
# 106269                                                5.0
# 106270                                                5.0
# 106271                                               33.0
# 106272                                               32.0
# 106273                                               40.0
# 106274                                              -91.0
# 106275                                              -64.0
# 106276                                              -25.0
# 106277                                               10.0
# 106278                                               12.0
# 106279                                               21.0
# 106280                                               33.0
#
#         parks_percent_change_from_baseline  \
# 98786                                  3.0
# 98787                                -22.0
# 98788                                  2.0
# 98789                                 12.0
# 98790                                 12.0
# 98791                                 -4.0
# 98792                                  6.0
# 98793                                -23.0
# 98794                                -37.0
# 98795                                -23.0
# 98796                                  9.0
# 98797                                -12.0
# 98798                                -17.0
# 98799                                 -1.0
# 98800                                -22.0
# 98801                                 11.0
# 98802                                -16.0
# 98803                                 24.0
# 98804                                 20.0
# 98805                                 -7.0
# 98806                                 10.0
# 98807                                 31.0
# 98808                                 -9.0
# 98809                                  1.0
# 98810                                 -5.0
# 98811                                 21.0
# 98812                                 -5.0
# 98813                                -20.0
# 98814                                 -4.0
# 98815                                 15.0
# ...                                    ...
# 106251                                 NaN
# 106252                                 NaN
# 106253                                 NaN
# 106254                                 NaN
# 106255                                 5.0
# 106256                                 NaN
# 106257                                 NaN
# 106258                                 NaN
# 106259                                 NaN
# 106260                                 NaN
# 106261                                 NaN
# 106262                                13.0
# 106263                                 NaN
# 106264                                 NaN
# 106265                                 NaN
# 106266                                 NaN
# 106267                                 NaN
# 106268                                 NaN
# 106269                                 NaN
# 106270                                 NaN
# 106271                                 NaN
# 106272                               -22.0
# 106273                                 NaN
# 106274                                 NaN
# 106275                               -27.0
# 106276                               -61.0
# 106277                                 NaN
# 106278                                 NaN
# 106279                                 NaN
# 106280                                 NaN
#
#         transit_stations_percent_change_from_baseline  \
# 98786                                             9.0
# 98787                                            14.0
# 98788                                             3.0
# 98789                                             0.0
# 98790                                            -2.0
# 98791                                            -1.0
# 98792                                             6.0
# 98793                                            11.0
# 98794                                             3.0
# 98795                                           -12.0
# 98796                                            -9.0
# 98797                                            -9.0
# 98798                                           -12.0
# 98799                                            -4.0
# 98800                                             3.0
# 98801                                             5.0
# 98802                                            -1.0
# 98803                                            -3.0
# 98804                                            -4.0
# 98805                                            -7.0
# 98806                                             1.0
# 98807                                             5.0
# 98808                                            -1.0
# 98809                                            -5.0
# 98810                                            -7.0
# 98811                                           -11.0
# 98812                                           -17.0
# 98813                                           -34.0
# 98814                                           -37.0
# 98815                                           -41.0
# ...                                               ...
# 106251                                          -38.0
# 106252                                          -45.0
# 106253                                          -36.0
# 106254                                          -38.0
# 106255                                          -35.0
# 106256                                          -41.0
# 106257                                          -42.0
# 106258                                          -39.0
# 106259                                          -43.0
# 106260                                          -37.0
# 106261                                          -41.0
# 106262                                          -26.0
# 106263                                          -33.0
# 106264                                          -46.0
# 106265                                          -46.0
# 106266                                          -49.0
# 106267                                          -45.0
# 106268                                          -53.0
# 106269                                          -33.0
# 106270                                          -56.0
# 106271                                          -57.0
# 106272                                          -55.0
# 106273                                          -55.0
# 106274                                          -64.0
# 106275                                          -59.0
# 106276                                          -59.0
# 106277                                          -53.0
# 106278                                          -52.0
# 106279                                          -51.0
# 106280                                          -58.0
#
#         workplaces_percent_change_from_baseline  \
# 98786                                      -1.0
# 98787                                      -3.0
# 98788                                       1.0
# 98789                                       2.0
# 98790                                       1.0
# 98791                                       0.0
# 98792                                      -4.0
# 98793                                      -3.0
# 98794                                      -4.0
# 98795                                     -22.0
# 98796                                     -20.0
# 98797                                     -20.0
# 98798                                     -21.0
# 98799                                     -21.0
# 98800                                      -4.0
# 98801                                      -1.0
# 98802                                       0.0
# 98803                                       1.0
# 98804                                       2.0
# 98805                                       1.0
# 98806                                       2.0
# 98807                                       0.0
# 98808                                      -1.0
# 98809                                       0.0
# 98810                                      -1.0
# 98811                                      -2.0
# 98812                                      -3.0
# 98813                                     -14.0
# 98814                                      -7.0
# 98815                                     -12.0
# ...                                         ...
# 106251                                    -26.0
# 106252                                    -31.0
# 106253                                    -24.0
# 106254                                      3.0
# 106255                                     -3.0
# 106256                                    -34.0
# 106257                                    -31.0
# 106258                                    -27.0
# 106259                                    -32.0
# 106260                                    -26.0
# 106261                                     -4.0
# 106262                                      4.0
# 106263                                    -32.0
# 106264                                    -38.0
# 106265                                    -45.0
# 106266                                    -49.0
# 106267                                    -44.0
# 106268                                    -15.0
# 106269                                     -3.0
# 106270                                    -59.0
# 106271                                    -58.0
# 106272                                    -53.0
# 106273                                    -65.0
# 106274                                    -84.0
# 106275                                    -40.0
# 106276                                    -13.0
# 106277                                    -66.0
# 106278                                    -65.0
# 106279                                    -61.0
# 106280                                    -69.0
#
#         residential_percent_change_from_baseline      date2
# 98786                                        0.0 2020-02-15
# 98787                                        1.0 2020-02-16
# 98788                                        0.0 2020-02-17
# 98789                                        0.0 2020-02-18
# 98790                                        0.0 2020-02-19
# 98791                                        1.0 2020-02-20
# 98792                                        0.0 2020-02-21
# 98793                                        0.0 2020-02-22
# 98794                                        0.0 2020-02-23
# 98795                                        3.0 2020-02-24
# 98796                                        2.0 2020-02-25
# 98797                                        2.0 2020-02-26
# 98798                                        3.0 2020-02-27
# 98799                                        2.0 2020-02-28
# 98800                                        0.0 2020-02-29
# 98801                                       -1.0 2020-03-01
# 98802                                        1.0 2020-03-02
# 98803                                        0.0 2020-03-03
# 98804                                        0.0 2020-03-04
# 98805                                        1.0 2020-03-05
# 98806                                        1.0 2020-03-06
# 98807                                        0.0 2020-03-07
# 98808                                        1.0 2020-03-08
# 98809                                        1.0 2020-03-09
# 98810                                        2.0 2020-03-10
# 98811                                        2.0 2020-03-11
# 98812                                        3.0 2020-03-12
# 98813                                        8.0 2020-03-13
# 98814                                        6.0 2020-03-14
# 98815                                        5.0 2020-03-15
# ...                                          ...        ...
# 106251                                      11.0 2020-12-02
# 106252                                      14.0 2020-12-03
# 106253                                      11.0 2020-12-04
# 106254                                       6.0 2020-12-05
# 106255                                       NaN 2020-12-06
# 106256                                      13.0 2020-12-07
# 106257                                      12.0 2020-12-08
# 106258                                      11.0 2020-12-09
# 106259                                      13.0 2020-12-10
# 106260                                      12.0 2020-12-11
# 106261                                       8.0 2020-12-12
# 106262                                       NaN 2020-12-13
# 106263                                      11.0 2020-12-14
# 106264                                      16.0 2020-12-15
# 106265                                      16.0 2020-12-16
# 106266                                      18.0 2020-12-17
# 106267                                      16.0 2020-12-18
# 106268                                      10.0 2020-12-19
# 106269                                       NaN 2020-12-20
# 106270                                      18.0 2020-12-21
# 106271                                      18.0 2020-12-22
# 106272                                      17.0 2020-12-23
# 106273                                      18.0 2020-12-24
# 106274                                      20.0 2020-12-25
# 106275                                       9.0 2020-12-26
# 106276                                       NaN 2020-12-27
# 106277                                      18.0 2020-12-28
# 106278                                      20.0 2020-12-29
# 106279                                      17.0 2020-12-30
# 106280                                      17.0 2020-12-31
#
# [7495 rows x 16 columns]

# %% [markdown]
# #### 6. Sort the data in ascending order of time and save it as 'df_province_largest'

# %%
df_province_largest = Utrecht.sort_values(by='date2')

# %%
# Execute the cell with the following command to visualize the results
df_province_largest.plot('date', 'workplaces_percent_change_from_baseline')

df_province_largest.resample('7D', on='date2').sum()['workplaces_percent_change_from_baseline'].plot()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-63-0a9f03fb012d> in <module>
#       2 df_province_largest.plot('date', 'workplaces_percent_change_from_baseline')
#       3
# ----> 4 df_province_largest.resample('7D', on='date2').sum()['workplaces_percent_change_from_baseline'].plot()
#
# ~\Documents\school\lib\site-packages\pandas\plotting\_core.py in __call__(self, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    2740                            colormap=colormap, table=table, yerr=yerr,
#    2741                            xerr=xerr, label=label, secondary_y=secondary_y,
# -> 2742                            **kwds)
#    2743     __call__.__doc__ = plot_series.__doc__
#    2744
#
# ~\Documents\school\lib\site-packages\pandas\plotting\_core.py in plot_series(data, kind, ax, figsize, use_index, title, grid, legend, style, logx, logy, loglog, xticks, yticks, xlim, ylim, rot, fontsize, colormap, table, yerr, xerr, label, secondary_y, **kwds)
#    1996                  yerr=yerr, xerr=xerr,
#    1997                  label=label, secondary_y=secondary_y,
# -> 1998                  **kwds)
#    1999
#    2000
#
# ~\Documents\school\lib\site-packages\pandas\plotting\_core.py in _plot(data, x, y, subplots, ax, kind, **kwds)
#    1799         plot_obj = klass(data, subplots=subplots, ax=ax, kind=kind, **kwds)
#    1800
# -> 1801     plot_obj.generate()
#    1802     plot_obj.draw()
#    1803     return plot_obj.result
#
# ~\Documents\school\lib\site-packages\pandas\plotting\_core.py in generate(self)
#     255
#     256         for ax in self.axes:
# --> 257             self._post_plot_logic_common(ax, self.data)
#     258             self._post_plot_logic(ax, self.data)
#     259
#
# ~\Documents\school\lib\site-packages\pandas\plotting\_core.py in _post_plot_logic_common(self, ax, data)
#     396                 ax.set_xticklabels(xticklabels)
#     397             self._apply_axis_properties(ax.xaxis, rot=self.rot,
# --> 398                                         fontsize=self.fontsize)
#     399             self._apply_axis_properties(ax.yaxis, fontsize=self.fontsize)
#     400
#
# ~\Documents\school\lib\site-packages\pandas\plotting\_core.py in _apply_axis_properties(self, axis, rot, fontsize)
#     470
#     471     def _apply_axis_properties(self, axis, rot=None, fontsize=None):
# --> 472         labels = axis.get_majorticklabels() + axis.get_minorticklabels()
#     473         for label in labels:
#     474             if rot is not None:
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1227     def __call__(self):
#    1228         'Return the locations of the ticks'
# -> 1229         self.refresh()
#    1230         return self._locator()
#    1231
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1247     def refresh(self):
#    1248         'Refresh internal information based on current limits.'
# -> 1249         dmin, dmax = self.viewlim_to_dt()
#    1250         self._locator = self.get_locator(dmin, dmax)
#    1251
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#     998                              'often happens if you pass a non-datetime '
#     999                              'value to an axis that has datetime units'
# -> 1000                              .format(vmin))
#    1001         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1002
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# Error in callback <function install_repl_displayhook.<locals>.post_execute at 0x00000159709DA620> (for post_execute):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Documents\school\lib\site-packages\matplotlib\pyplot.py in post_execute()
#     107             def post_execute():
#     108                 if matplotlib.is_interactive():
# --> 109                     draw_all()
#     110
#     111             # IPython >= 2
#
# ~\Documents\school\lib\site-packages\matplotlib\_pylab_helpers.py in draw_all(cls, force)
#     130         for f_mgr in cls.get_all_fig_managers():
#     131             if force or f_mgr.canvas.figure.stale:
# --> 132                 f_mgr.canvas.draw_idle()
#     133
#     134 atexit.register(Gcf.destroy_all)
#
# ~\Documents\school\lib\site-packages\matplotlib\backend_bases.py in draw_idle(self, *args, **kwargs)
#    1897         if not self._is_idle_drawing:
#    1898             with self._idle_draw_cntx():
# -> 1899                 self.draw(*args, **kwargs)
#    1900
#    1901     def draw_cursor(self, event):
#
# ~\Documents\school\lib\site-packages\matplotlib\backends\backend_agg.py in draw(self)
#     400         toolbar = self.toolbar
#     401         try:
# --> 402             self.figure.draw(self.renderer)
#     403             # A GUI class may be need to update a window using this draw, so
#     404             # don't forget to call the superclass.
#
# ~\Documents\school\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\Documents\school\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1647
#    1648             mimage._draw_list_compositing_images(
# -> 1649                 renderer, self, artists, self.suppressComposite)
#    1650
#    1651             renderer.close_group('figure')
#
# ~\Documents\school\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~\Documents\school\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\Documents\school\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2626             renderer.stop_rasterizing()
#    2627
# -> 2628         mimage._draw_list_compositing_images(renderer, self, artists)
#    2629
#    2630         renderer.close_group('axes')
#
# ~\Documents\school\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     136     if not_composite or not has_images:
#     137         for a in artists:
# --> 138             a.draw(renderer)
#     139     else:
#     140         # Composite any adjacent images together
#
# ~\Documents\school\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      48                 renderer.start_filter()
#      49
# ---> 50             return draw(artist, renderer, *args, **kwargs)
#      51         finally:
#      52             if artist.get_agg_filter() is not None:
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1183         renderer.open_group(__name__)
#    1184
# -> 1185         ticks_to_draw = self._update_ticks(renderer)
#    1186         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1187                                                                 renderer)
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in _update_ticks(self, renderer)
#    1021
#    1022         interval = self.get_view_interval()
# -> 1023         tick_tups = list(self.iter_ticks())  # iter_ticks calls the locator
#    1024         if self._smart_bounds and tick_tups:
#    1025             # handle inverted limits
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in iter_ticks(self)
#     965         Iterate through all of the major and minor ticks.
#     966         """
# --> 967         majorLocs = self.major.locator()
#     968         majorTicks = self.get_major_ticks(len(majorLocs))
#     969         self.major.formatter.set_locs(majorLocs)
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1227     def __call__(self):
#    1228         'Return the locations of the ticks'
# -> 1229         self.refresh()
#    1230         return self._locator()
#    1231
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1247     def refresh(self):
#    1248         'Refresh internal information based on current limits.'
# -> 1249         dmin, dmax = self.viewlim_to_dt()
#    1250         self._locator = self.get_locator(dmin, dmax)
#    1251
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#     998                              'often happens if you pass a non-datetime '
#     999                              'value to an axis that has datetime units'
# -> 1000                              .format(vmin))
#    1001         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1002
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\Documents\school\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      37             display(
#      38                 figure_manager.canvas.figure,
# ---> 39                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      40             )
#      41     finally:
#
# ~\Documents\school\lib\site-packages\ipykernel\pylab\backend_inline.py in _fetch_figure_metadata(fig)
#     175         # the background is transparent
#     176         ticksLight = _is_light([label.get_color()
# --> 177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
#     179                                 for label in axis.get_ticklabels()])
#
# ~\Documents\school\lib\site-packages\ipykernel\pylab\backend_inline.py in <listcomp>(.0)
#     177                                 for axes in fig.axes
#     178                                 for axis in (axes.xaxis, axes.yaxis)
# --> 179                                 for label in axis.get_ticklabels()])
#     180         if ticksLight.size and (ticksLight == ticksLight[0]).all():
#     181             # there are one or more tick labels, all with the same lightness
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in get_ticklabels(self, minor, which)
#    1284         if minor:
#    1285             return self.get_minorticklabels()
# -> 1286         return self.get_majorticklabels()
#    1287
#    1288     def get_majorticklines(self):
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in get_majorticklabels(self)
#    1238     def get_majorticklabels(self):
#    1239         'Return a list of Text instances for the major ticklabels'
# -> 1240         ticks = self.get_major_ticks()
#    1241         labels1 = [tick.label1 for tick in ticks if tick.label1On]
#    1242         labels2 = [tick.label2 for tick in ticks if tick.label2On]
#
# ~\Documents\school\lib\site-packages\matplotlib\axis.py in get_major_ticks(self, numticks)
#    1389         'get the tick instances; grow as necessary'
#    1390         if numticks is None:
# -> 1391             numticks = len(self.get_major_locator()())
#    1392
#    1393         while len(self.majorTicks) < numticks:
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in __call__(self)
#    1227     def __call__(self):
#    1228         'Return the locations of the ticks'
# -> 1229         self.refresh()
#    1230         return self._locator()
#    1231
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in refresh(self)
#    1247     def refresh(self):
#    1248         'Refresh internal information based on current limits.'
# -> 1249         dmin, dmax = self.viewlim_to_dt()
#    1250         self._locator = self.get_locator(dmin, dmax)
#    1251
#
# ~\Documents\school\lib\site-packages\matplotlib\dates.py in viewlim_to_dt(self)
#     998                              'often happens if you pass a non-datetime '
#     999                              'value to an axis that has datetime units'
# -> 1000                              .format(vmin))
#    1001         return num2date(vmin, self.tz), num2date(vmax, self.tz)
#    1002
#
# ValueError: view limit minimum 0.0 is less than 1 and is an invalid Matplotlib date value. This often happens if you pass a non-datetime value to an axis that has datetime units

# %% [markdown]
# #### 7. Compare the results above with the results in the google mobility report pdf of your selected province. Discuss the differences and similarities. Please save the mobility report pdf that you use to compare the results with! An example mobility report pdf can be found [here](https://www.gstatic.com/covid19/mobility/2021-09-01_AW_Mobility_Report_en.pdf)
